# %%
from tkinter import *
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
import numpy as np

# %%
linestyle_str = [
     ('solid', 'solid'),      # Same as (0, ()) or '-'
     ('dotted', 'dotted'),    # Same as (0, (1, 1)) or '.'
     ('dashed', 'dashed'),    # Same as '--'
     ('dashdot', 'dashdot')]  # Same as '-.'

linestyle_tuple = [
     ('loosely dotted',        (0, (1, 10))),
     ('dotted',                (0, (1, 1))),
     ('densely dotted',        (0, (1, 1))),

     ('loosely dashed',        (0, (5, 10))),
     ('dashed',                (0, (5, 5))),
     ('densely dashed',        (0, (5, 1))),

     ('loosely dashdotted',    (0, (3, 10, 1, 10))),
     ('dashdotted',            (0, (3, 5, 1, 5))),
     ('densely dashdotted',    (0, (3, 1, 1, 1))),

     ('dashdotdotted',         (0, (3, 5, 1, 5, 1, 5))),
     ('loosely dashdotdotted', (0, (3, 10, 1, 10, 1, 10))),
     ('densely dashdotdotted', (0, (3, 1, 1, 1, 1, 1)))]

# %%
def utility_compare_uniform(Hstore, Honline, Lstore, Lonline):
    if max(Lstore, Lonline) >= 0 and max(Hstore, Honline) >= 0:
        if Lstore > Lonline:
            return "BS"
        else:
            return "BO"

    elif max(Lstore, Lonline) >= 0 and max(Hstore, Honline) < 0:
        if Lstore > Lonline:
            return "LS"
        else:
            return "LO"

    elif max(Lstore, Lonline) < 0 and max(Hstore, Honline) >= 0:
        if Hstore > Honline:
            return "HS"
        else:
            return "HO"

    elif max(Lstore, Lonline) < 0 and max(Hstore, Honline) < 0:
        return "No sales"
    else:
        raise Exception("other cases")


def utility_compare_dual(Hstore, Honline, Hshowrooming, Lstore, Lonline, Lshowrooming):
    # due to the the comparison between the three cases is independent of theta, we have:
    if Honline >= max(Hstore, Hshowrooming, 0):  # also implies Honline >= max(Hstore, Hshowrooming)
        if Lonline >= 0:
            return "BO"
        else:
            return "HO"
    elif Hstore >= max(Hshowrooming, 0):
        if Lstore >= 0:
            return "BS"
        else:
            return "HS"

    elif Hshowrooming >= 0:
        if Lshowrooming >= 0:
            return "BSR"
        else:
            return "HSR"
    elif max(Lstore, Lshowrooming, Lonline) < 0:
        return "NoSales"
    else:
        raise Exception("Other cases occur!")


class NumSolver:
    def __init__(self, V=0.8, GAMMA=0.2, P_HAT=0.1, DELTA_h=0.6, DELTA_l=0.2, CR=0.7):
        self.V = V
        self.GAMMA = GAMMA
        self.P_HAT = P_HAT
        self.DELTA_h = DELTA_h
        self.DELTA_l = DELTA_l
        self.CR = CR

    def get_utility(self, TYPE, p, poff, c, con):

        if p >= self.P_HAT:
            delta = self.DELTA_h
        else:
            delta = self.DELTA_l

        if TYPE == "H":
            theta = 1.00
        elif TYPE == "L":
            theta = self.V
        else:
            raise Exception("Consumer Type Error!")

        u_store = (theta - poff) / 2 - c
        u_online = (theta - 2 * p + delta * p) / 2 - con
        u_showrooming = (theta - p - con) / 2 - c

        u_store = int(u_store * 10000 + 0.5) / 10000
        u_online = int(u_online * 10000 + 0.5) / 10000
        u_showrooming = int(u_showrooming * 10000 + 0.5) / 10000

        return u_store, u_online, u_showrooming

    def get_profit(self, p, poff, c, con):

        if p >= self.P_HAT:
            delta = self.DELTA_h
        else:
            delta = self.DELTA_l

        H_u_store, H_u_online, H_u_showrooming = self.get_utility("H", p, poff, c, con)
        L_u_store, L_u_online, L_u_showrooming = self.get_utility("L", p, poff, c, con)

        # High type
        pi_H_showrooming = 1 / 4 * self.GAMMA * p * (
            [1 if (H_u_showrooming >= 0 and H_u_showrooming > max(H_u_store, H_u_online)) else 0][0])
        pi_H_store = 1 / 4 * self.GAMMA * poff * (
            [1 if (H_u_store >= max(H_u_showrooming, 0) and H_u_store > H_u_online) else 0][0])
        pi_H_online = 1 / 4 * self.GAMMA * (p + (1 - delta) * p - delta * self.CR) * (
            [1 if H_u_online >= max(H_u_showrooming, H_u_store, 0) else 0][0])

        # Low type
        pi_L_showrooming = 1 / 4 * (1 - self.GAMMA) * p * (
            [1 if (L_u_showrooming >= 0 and L_u_showrooming > max(L_u_store, L_u_online)) else 0][0])
        pi_L_store = 1 / 4 * (1 - self.GAMMA) * poff * (
            [1 if (L_u_store >= max(L_u_showrooming, 0) and L_u_store > L_u_online) else 0][0])
        pi_L_online = 1 / 4 * (1 - self.GAMMA) * (p + (1 - delta) * p - delta * self.CR) * (
            [1 if L_u_online >= max(L_u_showrooming, L_u_store, 0) else 0][0])

        expected_profit = pi_H_online + pi_H_store + pi_H_showrooming + pi_L_online + pi_L_store + pi_L_showrooming

        return expected_profit


class Run():
    def __init__(self, precision):

        self.PropShow = 0.1

        self.PropOffOnly = 0.1
        
        self.HighReturnProb = 0.4

        self.LowReturnProb =0.4

        self.PriceThreshold = 0.1
        
        self.ValLow = 0.52
        
        self.PropHigh = 0.25

        self.OnlineCost = 0.14
        
        self.ReturnCostRet = 0.3
        
        self.precision = precision
        
        self.res_dict = {}

        self.read_params()
        


    def plot_figures(self, ALPHA, BETA, V, GAMMA, P_HAT, DELTA_h, DELTA_l, CR, con, precision):
        self.solver = NumSolver(V, GAMMA, P_HAT, DELTA_h, DELTA_l, CR)

        optimal_profits_u = []
        optimal_prices_u = []

        optimal_profits_d = []
        optimal_prices_d = []

        behavior_tuples_both = []
        behavior_tuples_show = []
        behavior_tuples_off = []

        for current_c in np.arange(0, 0.35, precision):
            optimal_profit_u = 0
            optimal_price_u = 0
            optimal_profit_d = 0
            optimal_online_price_d = 0
            optimal_offline_price_d = 0

            for p_current in np.arange(0, 1, 0.005):
                profit_current_u = (1 - ALPHA - BETA) * self.solver.get_profit(p=p_current, poff=p_current, c=current_c,
                                                                               con=con) \
                                   + ALPHA * self.solver.get_profit(p=p_current, poff=p_current, c=current_c, con=0) \
                                   + BETA * self.solver.get_profit(p=p_current, poff=p_current, c=current_c, con=10)
                # find optimal uniform prices
                if profit_current_u > optimal_profit_u:
                    optimal_profit_u = profit_current_u
                    optimal_price_u = p_current

                # poff=pon+con, 1-alpha-beta segment does not conduct showrooming poff=V, 1-alpha-beta segment
                # conducts showrooming. The offline optimally serve all offline-only consumers poff=1, 1-alpha-beta
                # segment conducts showrooming. The offline optimally serve high type offline-only consumers
                OfflinePriceScenarios = [p_current + con]
                for poff_current in OfflinePriceScenarios:
                    profit_current_d = (1 - ALPHA - BETA) * self.solver.get_profit(p=p_current, poff=poff_current,
                                                                                   c=current_c, con=con) \
                                       + ALPHA * self.solver.get_profit(p=p_current, poff=poff_current, c=current_c, con=0) \
                                       + BETA * self.solver.get_profit(p=p_current, poff=poff_current, c=current_c, con=10)

                    if profit_current_d > optimal_profit_d:
                        optimal_profit_d = profit_current_d
                        optimal_online_price_d = p_current
                        optimal_offline_price_d = poff_current

            behavior_tuple_both = self.analyze_behavior(current_c, con, optimal_price_u, optimal_online_price_d,
                                                        optimal_offline_price_d)
            behavior_tuple_show = self.analyze_behavior(current_c, 0, optimal_price_u, optimal_online_price_d,
                                                       optimal_offline_price_d)
            behavior_tuple_off = self.analyze_behavior(current_c, 10, optimal_price_u, optimal_online_price_d,
                                                      optimal_offline_price_d)

            optimal_profits_u.append(optimal_profit_u)
            optimal_prices_u.append(optimal_price_u)
            optimal_profits_d.append(optimal_profit_d)
            optimal_prices_d.append((optimal_online_price_d, optimal_offline_price_d))
            behavior_tuples_both.append(behavior_tuple_both)
            behavior_tuples_show.append(behavior_tuple_show)
            behavior_tuples_off.append(behavior_tuple_off)
        
        for current_c, price_u, price_d, profit_u, profit_d in zip(
                np.arange(0, 0.35, precision), optimal_prices_u, optimal_prices_d, optimal_profits_u, optimal_profits_d):
            behavior_u_both, behavior_d_both = self.analyze_behavior(current_c, con, price_u, price_d[0], price_d[1])
            behavior_u_show, behavior_d_show = self.analyze_behavior(current_c, 0, price_u, price_d[0], price_d[1])
            behavior_u_off, behavior_d_off = self.analyze_behavior(current_c, 10, price_u, price_d[0], price_d[1])
            print("current c: {:.3f}, price_u: {:.3f}, price_d_on: {:.3f}, price_d_off: {:.3f}".format(
                current_c, price_u, price_d[0], price_d[1]))
            print("behavior of both-channel u:{}, d:{}".format(behavior_u_both, behavior_d_both))
            print("behavior of show u:{}, d:{}".format(behavior_u_show, behavior_d_show))
            print("behavior of off u:{}, d:{}".format(behavior_u_off, behavior_d_off))
            print("profit_u: {:.5f}, profit_d: {:.5f}".format(profit_u, profit_d))
        
#         fig1 = plt.figure(figsize=(8, 4.5))
#         ax1 = fig1.add_subplot(1, 1, 1)
#         ax1.plot(np.arange(0, 0.5, 0.01), optimal_profits_u, 'r', label="Uniform pricing",
#                  linestyle='dotted',linewidth=2)
#         ax1.plot(np.arange(0, 0.5, 0.01), optimal_profits_d, label="Dual pricing",
#                  linestyle='dashdot',linewidth=2)
#         ax1.set_ylabel("Profits", fontsize =16)
#         ax1.set_xlabel("c", fontsize =16)
#         #ax1.set_title("Profits", fontsize =16)
#        # ax1.grid(axis='y', color ='#666666',lw=0.25)
#         ax1.legend(prop=dict(size=9), frameon=False)
        
        
#         fig2 = plt.figure(figsize=(8, 4.5))
#         ax2 = fig2.add_subplot(1, 1, 1)
#         ax2.plot(np.arange(0, 0.5, 0.01), optimal_prices_u, 'r', label="Uniform pricing",
#                  linestyle='dotted',linewidth=2)
#         ax2.plot(np.arange(0, 0.5, 0.01), [x[0] for x in optimal_prices_d], 
#                  label="Online price in Dual pricing", linestyle="dashdot", linewidth=2)
#         ax2.plot(np.arange(0, 0.5, 0.01), [x[1] for x in optimal_prices_d], 
#                  label="Offline price in Dual pricing",linestyle="--" ,linewidth=2)
#         ax2.set_ylabel("Prices", fontsize =16)
#         ax2.set_xlabel("c", fontsize =16)
#         ax2.legend(prop=dict(size=9), frameon=False,loc=4)
#        # ax2.grid(axis='y', color ='#666666',lw=0.25)
        
#         ## adjust figures
#         ax1.set_xlim([0, 0.5])
#         ax1.set_ylim([0, 0.14])
#         ax1.axvline(x=0.12, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
#         ax1.axvline(x=0.17, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
#         ax1.axvline(x=0.23, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
#         ax1.axvline(x=0.24, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
#         ax1.text(0.13,0.1, 'zone 1')
#         ax1.annotate("zone 2", xy=(0.235, 0.1), xytext=(0.26, 0.1),arrowprops=dict(arrowstyle="<-"))
        
#         ax2.set_xlim([0,0.5])
#         ax2.set_ylim([0,0.8])
#         ax2.axvline(x=0.12, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
#         ax2.axvline(x=0.17, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
#         ax2.axvline(x=0.23, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
#         ax2.axvline(x=0.24, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
#         ax2.text(0.13,0.1, 'zone 1')
#         ax2.annotate("zone 2", xy=(0.235, 0.2), xytext=(0.26, 0.2),arrowprops=dict(arrowstyle="<-"))
        
#         # save figures
        
#         #fig1.savefig("./MR_PFT.pdf")
#        # fig2.savefig("./MR_PCE.pdf")
        
        plt.show()

        res_dict = {"profit_u": optimal_profits_u, "profit_d": optimal_profits_d,
                    "price_u": optimal_prices_u, "price_d": optimal_prices_d,
                    "behavior_both": behavior_tuples_both, "behavior_show": behavior_tuples_show,
                    "behavior_off": behavior_tuples_off}
        self.res_dict = res_dict

    def read_params(self):
        alpha = float(self.PropShow)
        beta = float(self.PropOffOnly)
        if alpha + beta > 1:
            raise Exception("alpha + beta should be less than 1")

        delta_h = float(self.HighReturnProb)
        delta_l = float(self.LowReturnProb)
        phat = float(self.PriceThreshold)
        V = float(self.ValLow)
        gamma = float(self.PropHigh)

        con = float(self.OnlineCost)
        cr = float(self.ReturnCostRet)

        data_dict = self.plot_figures(ALPHA=alpha, BETA=beta, V=V, GAMMA=gamma, P_HAT=phat, DELTA_h=delta_h,
                                      DELTA_l=delta_l, CR=cr, con=con ,precision=self.precision)

    def analyze_behavior(self, c, con, uniform_price, dual_online_price, dual_offline_price):
        H_u_store, H_u_online, _ = self.solver.get_utility("H", uniform_price, uniform_price, c, con)
        L_u_store, L_u_online, _ = self.solver.get_utility("L", uniform_price, uniform_price, c, con)
        behavior_uniform = utility_compare_uniform(H_u_store, H_u_online, L_u_store, L_u_online)

        H_d_store, H_d_online, H_d_showrooming = self.solver.get_utility("H", dual_online_price, dual_offline_price, c,
                                                                         con)
        L_d_store, L_d_online, L_d_showrooming = self.solver.get_utility("L", dual_online_price, dual_offline_price, c,
                                                                         con)

        behavior_dual = utility_compare_dual(H_d_store, H_d_online, H_d_showrooming, L_d_store, L_d_online,
                                             L_d_showrooming)

        return behavior_uniform, behavior_dual

# %%
prec=0.0025
num = Run(precision=prec)
# Out:
# current c: 0.000, price_u: 0.520, price_d_on: 0.380, price_d_off: 0.520
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.13000, profit_d: 0.12650
# current c: 0.003, price_u: 0.515, price_d_on: 0.375, price_d_off: 0.515
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.12875, profit_d: 0.12525
# current c: 0.005, price_u: 0.510, price_d_on: 0.370, price_d_off: 0.510
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.12750, profit_d: 0.12400
# current c: 0.007, price_u: 0.505, price_d_on: 0.365, price_d_off: 0.505
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.12625, profit_d: 0.12275
# current c: 0.010, price_u: 0.500, price_d_on: 0.360, price_d_off: 0.500
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.12500, profit_d: 0.12150
# current c: 0.013, price_u: 0.495, price_d_on: 0.355, price_d_off: 0.495
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.12375, profit_d: 0.12025
# current c: 0.015, price_u: 0.490, price_d_on: 0.350, price_d_off: 0.490
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.12250, profit_d: 0.11900
# current c: 0.018, price_u: 0.485, price_d_on: 0.345, price_d_off: 0.485
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.12125, profit_d: 0.11775
# current c: 0.020, price_u: 0.480, price_d_on: 0.340, price_d_off: 0.480
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.12000, profit_d: 0.11650
# current c: 0.022, price_u: 0.475, price_d_on: 0.335, price_d_off: 0.475
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.11875, profit_d: 0.11525
# current c: 0.025, price_u: 0.470, price_d_on: 0.330, price_d_off: 0.470
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.11750, profit_d: 0.11400
# current c: 0.028, price_u: 0.465, price_d_on: 0.325, price_d_off: 0.465
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.11625, profit_d: 0.11275
# current c: 0.030, price_u: 0.460, price_d_on: 0.320, price_d_off: 0.460
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.11500, profit_d: 0.11150
# current c: 0.033, price_u: 0.455, price_d_on: 0.315, price_d_off: 0.455
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.11375, profit_d: 0.11025
# current c: 0.035, price_u: 0.450, price_d_on: 0.310, price_d_off: 0.450
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.11250, profit_d: 0.10900
# current c: 0.037, price_u: 0.445, price_d_on: 0.305, price_d_off: 0.445
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.11125, profit_d: 0.10775
# current c: 0.040, price_u: 0.440, price_d_on: 0.300, price_d_off: 0.440
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.11000, profit_d: 0.10650
# current c: 0.043, price_u: 0.435, price_d_on: 0.295, price_d_off: 0.435
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.10875, profit_d: 0.10525
# current c: 0.045, price_u: 0.430, price_d_on: 0.290, price_d_off: 0.430
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.10750, profit_d: 0.10400
# current c: 0.048, price_u: 0.425, price_d_on: 0.285, price_d_off: 0.425
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.10625, profit_d: 0.10275
# current c: 0.050, price_u: 0.420, price_d_on: 0.280, price_d_off: 0.420
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.10500, profit_d: 0.10150
# current c: 0.052, price_u: 0.415, price_d_on: 0.275, price_d_off: 0.415
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.10375, profit_d: 0.10025
# current c: 0.055, price_u: 0.410, price_d_on: 0.270, price_d_off: 0.410
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.10250, profit_d: 0.09900
# current c: 0.058, price_u: 0.405, price_d_on: 0.265, price_d_off: 0.405
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.10125, profit_d: 0.09775
# current c: 0.060, price_u: 0.400, price_d_on: 0.260, price_d_off: 0.400
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.10000, profit_d: 0.09650
# current c: 0.062, price_u: 0.395, price_d_on: 0.255, price_d_off: 0.395
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.09875, profit_d: 0.09525
# current c: 0.065, price_u: 0.390, price_d_on: 0.250, price_d_off: 0.390
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.09750, profit_d: 0.09400
# current c: 0.068, price_u: 0.385, price_d_on: 0.245, price_d_off: 0.385
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.09625, profit_d: 0.09275
# current c: 0.070, price_u: 0.380, price_d_on: 0.240, price_d_off: 0.380
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BSR
# behavior of off u:BS, d:BS
# profit_u: 0.09500, profit_d: 0.09150
# current c: 0.072, price_u: 0.375, price_d_on: 0.235, price_d_off: 0.375
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.09375, profit_d: 0.09078
# current c: 0.075, price_u: 0.370, price_d_on: 0.230, price_d_off: 0.370
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.09250, profit_d: 0.08945
# current c: 0.077, price_u: 0.365, price_d_on: 0.225, price_d_off: 0.365
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.09125, profit_d: 0.08812
# current c: 0.080, price_u: 0.360, price_d_on: 0.220, price_d_off: 0.360
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.09000, profit_d: 0.08680
# current c: 0.083, price_u: 0.355, price_d_on: 0.215, price_d_off: 0.355
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.08875, profit_d: 0.08547
# current c: 0.085, price_u: 0.350, price_d_on: 0.210, price_d_off: 0.350
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.08750, profit_d: 0.08415
# current c: 0.088, price_u: 0.345, price_d_on: 0.205, price_d_off: 0.345
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.08625, profit_d: 0.08283
# current c: 0.090, price_u: 0.340, price_d_on: 0.200, price_d_off: 0.340
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.08500, profit_d: 0.08150
# current c: 0.092, price_u: 0.335, price_d_on: 0.195, price_d_off: 0.335
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.08375, profit_d: 0.08017
# current c: 0.095, price_u: 0.330, price_d_on: 0.190, price_d_off: 0.330
# behavior of both-channel u:BS, d:BS
# behavior of show u:BS, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.08250, profit_d: 0.07885
# current c: 0.098, price_u: 0.325, price_d_on: 0.185, price_d_off: 0.325
# behavior of both-channel u:BS, d:BS
# behavior of show u:BO, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.08313, profit_d: 0.07753
# current c: 0.100, price_u: 0.320, price_d_on: 0.180, price_d_off: 0.320
# behavior of both-channel u:BS, d:BS
# behavior of show u:BO, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.08180, profit_d: 0.07620
# current c: 0.103, price_u: 0.315, price_d_on: 0.175, price_d_off: 0.315
# behavior of both-channel u:BS, d:BS
# behavior of show u:BO, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.08047, profit_d: 0.07488
# current c: 0.105, price_u: 0.310, price_d_on: 0.170, price_d_off: 0.310
# behavior of both-channel u:BS, d:BS
# behavior of show u:BO, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.07915, profit_d: 0.07355
# current c: 0.107, price_u: 0.305, price_d_on: 0.165, price_d_off: 0.305
# behavior of both-channel u:BS, d:BS
# behavior of show u:BO, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.07783, profit_d: 0.07223
# current c: 0.110, price_u: 0.300, price_d_on: 0.160, price_d_off: 0.300
# behavior of both-channel u:BS, d:BS
# behavior of show u:BO, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.07650, profit_d: 0.07090
# current c: 0.113, price_u: 0.295, price_d_on: 0.155, price_d_off: 0.295
# behavior of both-channel u:BS, d:BS
# behavior of show u:BO, d:BO
# behavior of off u:BS, d:BS
# profit_u: 0.07517, profit_d: 0.06958
# current c: 0.115, price_u: 0.290, price_d_on: 0.630, price_d_off: 0.770
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.07385, profit_d: 0.04725
# current c: 0.118, price_u: 0.285, price_d_on: 0.625, price_d_off: 0.765
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.07253, profit_d: 0.04694
# current c: 0.120, price_u: 0.280, price_d_on: 0.620, price_d_off: 0.760
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.07120, profit_d: 0.04663
# current c: 0.122, price_u: 0.275, price_d_on: 0.615, price_d_off: 0.755
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.06988, profit_d: 0.04631
# current c: 0.125, price_u: 0.270, price_d_on: 0.610, price_d_off: 0.750
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.06855, profit_d: 0.04600
# current c: 0.128, price_u: 0.265, price_d_on: 0.605, price_d_off: 0.745
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.06723, profit_d: 0.04569
# current c: 0.130, price_u: 0.260, price_d_on: 0.600, price_d_off: 0.740
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.06590, profit_d: 0.04537
# current c: 0.133, price_u: 0.255, price_d_on: 0.595, price_d_off: 0.735
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.06458, profit_d: 0.04506
# current c: 0.135, price_u: 0.250, price_d_on: 0.590, price_d_off: 0.730
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.06325, profit_d: 0.04475
# current c: 0.138, price_u: 0.245, price_d_on: 0.585, price_d_off: 0.725
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.06193, profit_d: 0.04444
# current c: 0.140, price_u: 0.240, price_d_on: 0.580, price_d_off: 0.720
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.06060, profit_d: 0.04412
# current c: 0.143, price_u: 0.235, price_d_on: 0.575, price_d_off: 0.715
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.05928, profit_d: 0.04381
# current c: 0.145, price_u: 0.230, price_d_on: 0.570, price_d_off: 0.710
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.05795, profit_d: 0.04350
# current c: 0.147, price_u: 0.225, price_d_on: 0.565, price_d_off: 0.705
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.05663, profit_d: 0.04319
# current c: 0.150, price_u: 0.220, price_d_on: 0.560, price_d_off: 0.700
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.05530, profit_d: 0.04288
# current c: 0.152, price_u: 0.215, price_d_on: 0.555, price_d_off: 0.695
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.05398, profit_d: 0.04256
# current c: 0.155, price_u: 0.210, price_d_on: 0.550, price_d_off: 0.690
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.05265, profit_d: 0.04225
# current c: 0.158, price_u: 0.205, price_d_on: 0.545, price_d_off: 0.685
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HSR
# behavior of off u:BS, d:HS
# profit_u: 0.05133, profit_d: 0.04194
# current c: 0.160, price_u: 0.200, price_d_on: 0.530, price_d_off: 0.670
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HO
# behavior of off u:BS, d:HS
# profit_u: 0.05000, profit_d: 0.04224
# current c: 0.163, price_u: 0.195, price_d_on: 0.535, price_d_off: 0.675
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HO
# behavior of off u:BS, d:HS
# profit_u: 0.04868, profit_d: 0.04257
# current c: 0.165, price_u: 0.190, price_d_on: 0.530, price_d_off: 0.670
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HO
# behavior of off u:BS, d:HS
# profit_u: 0.04735, profit_d: 0.04224
# current c: 0.168, price_u: 0.185, price_d_on: 0.525, price_d_off: 0.665
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HO
# behavior of off u:BS, d:HS
# profit_u: 0.04602, profit_d: 0.04191
# current c: 0.170, price_u: 0.180, price_d_on: 0.520, price_d_off: 0.660
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HO
# behavior of off u:BS, d:HS
# profit_u: 0.04470, profit_d: 0.04158
# current c: 0.173, price_u: 0.175, price_d_on: 0.515, price_d_off: 0.655
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HO
# behavior of off u:BS, d:HS
# profit_u: 0.04338, profit_d: 0.04124
# current c: 0.175, price_u: 0.170, price_d_on: 0.510, price_d_off: 0.650
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HO
# behavior of off u:BS, d:HS
# profit_u: 0.04205, profit_d: 0.04091
# current c: 0.177, price_u: 0.165, price_d_on: 0.505, price_d_off: 0.645
# behavior of both-channel u:BS, d:HS
# behavior of show u:BO, d:HO
# behavior of off u:BS, d:HS
# profit_u: 0.04072, profit_d: 0.04058
# current c: 0.180, price_u: 0.640, price_d_on: 0.500, price_d_off: 0.640
# behavior of both-channel u:HS, d:HS
# behavior of show u:HS, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.04000, profit_d: 0.04025
# current c: 0.182, price_u: 0.635, price_d_on: 0.495, price_d_off: 0.635
# behavior of both-channel u:HS, d:HS
# behavior of show u:HS, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03969, profit_d: 0.03992
# current c: 0.185, price_u: 0.615, price_d_on: 0.490, price_d_off: 0.630
# behavior of both-channel u:HS, d:HS
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03999, profit_d: 0.03959
# current c: 0.188, price_u: 0.625, price_d_on: 0.485, price_d_off: 0.625
# behavior of both-channel u:HS, d:HS
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.04066, profit_d: 0.03926
# current c: 0.190, price_u: 0.620, price_d_on: 0.480, price_d_off: 0.620
# behavior of both-channel u:HS, d:HS
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.04032, profit_d: 0.03893
# current c: 0.193, price_u: 0.615, price_d_on: 0.475, price_d_off: 0.615
# behavior of both-channel u:HS, d:HS
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03999, profit_d: 0.03859
# current c: 0.195, price_u: 0.610, price_d_on: 0.470, price_d_off: 0.610
# behavior of both-channel u:HS, d:HS
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03966, profit_d: 0.03826
# current c: 0.198, price_u: 0.605, price_d_on: 0.465, price_d_off: 0.605
# behavior of both-channel u:HS, d:HS
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03933, profit_d: 0.03793
# current c: 0.200, price_u: 0.600, price_d_on: 0.460, price_d_off: 0.600
# behavior of both-channel u:HS, d:HS
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03900, profit_d: 0.03760
# current c: 0.203, price_u: 0.595, price_d_on: 0.455, price_d_off: 0.595
# behavior of both-channel u:HS, d:HS
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03867, profit_d: 0.03727
# current c: 0.205, price_u: 0.590, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03834, profit_d: 0.03744
# current c: 0.208, price_u: 0.585, price_d_on: 0.445, price_d_off: 0.585
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03801, profit_d: 0.03696
# current c: 0.210, price_u: 0.580, price_d_on: 0.440, price_d_off: 0.580
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03768, profit_d: 0.03648
# current c: 0.212, price_u: 0.575, price_d_on: 0.435, price_d_off: 0.575
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03734, profit_d: 0.03599
# current c: 0.215, price_u: 0.570, price_d_on: 0.430, price_d_off: 0.570
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03701, profit_d: 0.03551
# current c: 0.217, price_u: 0.565, price_d_on: 0.425, price_d_off: 0.565
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03668, profit_d: 0.03503
# current c: 0.220, price_u: 0.560, price_d_on: 0.420, price_d_off: 0.560
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03635, profit_d: 0.03455
# current c: 0.223, price_u: 0.555, price_d_on: 0.415, price_d_off: 0.555
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:HS
# profit_u: 0.03602, profit_d: 0.03407
# current c: 0.225, price_u: 0.550, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03569, profit_d: 0.03375
# current c: 0.228, price_u: 0.545, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03536, profit_d: 0.03375
# current c: 0.230, price_u: 0.540, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03503, profit_d: 0.03375
# current c: 0.233, price_u: 0.535, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03469, profit_d: 0.03375
# current c: 0.235, price_u: 0.530, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03436, profit_d: 0.03375
# current c: 0.238, price_u: 0.525, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03403, profit_d: 0.03375
# current c: 0.240, price_u: 0.520, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03370, profit_d: 0.03375
# current c: 0.242, price_u: 0.515, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03337, profit_d: 0.03375
# current c: 0.245, price_u: 0.510, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03304, profit_d: 0.03375
# current c: 0.247, price_u: 0.505, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03271, profit_d: 0.03375
# current c: 0.250, price_u: 0.500, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03238, profit_d: 0.03375
# current c: 0.253, price_u: 0.495, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HS, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03204, profit_d: 0.03375
# current c: 0.255, price_u: 0.325, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:BO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03203, profit_d: 0.03375
# current c: 0.258, price_u: 0.325, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:BO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03203, profit_d: 0.03375
# current c: 0.260, price_u: 0.325, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:BO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03203, profit_d: 0.03375
# current c: 0.263, price_u: 0.405, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03223, profit_d: 0.03375
# current c: 0.265, price_u: 0.415, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03319, profit_d: 0.03375
# current c: 0.268, price_u: 0.425, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03416, profit_d: 0.03375
# current c: 0.270, price_u: 0.430, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03464, profit_d: 0.03375
# current c: 0.273, price_u: 0.440, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03560, profit_d: 0.03375
# current c: 0.275, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03656, profit_d: 0.03375
# current c: 0.278, price_u: 0.445, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03608, profit_d: 0.03375
# current c: 0.280, price_u: 0.440, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03560, profit_d: 0.03375
# current c: 0.283, price_u: 0.435, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03512, profit_d: 0.03375
# current c: 0.285, price_u: 0.430, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03464, profit_d: 0.03375
# current c: 0.288, price_u: 0.425, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:HS, d:NoSales
# profit_u: 0.03416, profit_d: 0.03375
# current c: 0.290, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.292, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.295, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.297, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.300, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.302, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.305, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.307, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.310, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.312, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.315, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.318, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.320, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.323, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.325, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.328, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.330, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.333, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.335, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.338, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.340, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.343, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.345, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375
# current c: 0.348, price_u: 0.450, price_d_on: 0.450, price_d_off: 0.590
# behavior of both-channel u:HO, d:HO
# behavior of show u:HO, d:HO
# behavior of off u:No sales, d:NoSales
# profit_u: 0.03375, profit_d: 0.03375

# %%
num.res_dict.keys()
# Out:
# dict_keys(['profit_u', 'profit_d', 'price_u', 'price_d', 'behavior_both', 'behavior_show', 'behavior_off'])

# %%
min_c_ind = list( np.arange(0, 0.35, prec)).index(num.OnlineCost)
max_c_ind = list( np.arange(0, 0.35, prec)).index(0.31)
print(min_c_ind,max_c_ind)
# Out:
# 56 124

# %%
sel_c = np.arange(0, 0.35, prec)[min_c_ind:max_c_ind]
sel_prices_u = num.res_dict["price_u"][min_c_ind:max_c_ind]
sel_prices_d = num.res_dict["price_d"][min_c_ind:max_c_ind]
sel_profits_u = num.res_dict["profit_u"][min_c_ind:max_c_ind]
sel_profits_d = num.res_dict["profit_d"][min_c_ind:max_c_ind]

# %%
fig1 = plt.figure(figsize=(8, 4.5))
ax1 = fig1.add_subplot(1, 1, 1)
ax1.plot(sel_c, sel_profits_u,c='red', ls='--', ms=4, marker='^', markerfacecolor='none', label="Uniform pricing")
ax1.plot(sel_c, sel_profits_d, c='blue', ls='--', ms=4, marker='o',markerfacecolor='none', label="Dual pricing")

ax1.set_ylabel("Profits", fontsize =16)
ax1.set_xlabel("c", fontsize =16)
#ax1.set_title("Profits", fontsize =16)
# ax1.grid(axis='y', color ='#666666',lw=0.25)
ax1.legend(prop=dict(size=9), frameon=False)


fig2 = plt.figure(figsize=(8, 4.5))
ax2 = fig2.add_subplot(1, 1, 1)
ax2.plot(sel_c, sel_prices_u, c='red', ls='--', ms=4, marker='^', markerfacecolor='none',label="Uniform pricing")
ax2.plot(sel_c, [x[0] for x in sel_prices_d], c='blue', ls='--', ms=4, marker='o',  markerfacecolor='none',label="Online price in Dual pricing")
ax2.plot(sel_c, [x[1] for x in sel_prices_d],c='green',  ls='--', ms=4, marker='D',markerfacecolor='none',label="Offline price in Dual pricing")
ax2.set_ylabel("Prices", fontsize =16)
ax2.set_xlabel("c", fontsize =16)
ax2.legend(prop=dict(size=9), frameon=False,loc=4)
# ax2.grid(axis='y', color ='#666666',lw=0.25)

## adjust figures
ax1.set_xlim([0.14, 0.31])
ax1.set_ylim([0, 0.08])
ax1.axvline(x=0.1775, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
ax1.axvline(x=0.223, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
ax1.axvline(x=0.232, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
ax1.text(0.15,0.02, 'zone 1')
ax1.annotate("zone 2", xy=(0.225, 0.02), xytext=(0.24, 0.02),arrowprops=dict(arrowstyle="<-"))

ax2.set_xlim([0.14,0.31])
ax2.set_ylim([0,0.8])
ax2.axvline(x=0.1775, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
ax2.axvline(x=0.223, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
ax2.axvline(x=0.232, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
ax2.text(0.15,0.1, 'zone 1')
ax2.annotate("zone 2", xy=(0.225, 0.2), xytext=(0.24, 0.2),arrowprops=dict(arrowstyle="<-"))
# Out:
# Text(0.24, 0.2, 'zone 2')

# %%
# fig1 = plt.figure(figsize=(8, 4.5))
# ax1 = fig1.add_subplot(1, 1, 1)
# ax1.plot(sel_c, sel_profits_u, 'r', label="Uniform pricing",
#          linestyle=(0,(1,3)),linewidth=2)
# ax1.plot(sel_c, sel_profits_d, label="Dual pricing",
#          linestyle =(0, (3, 5, 1, 5)), linewidth=2)

# ax1.set_ylabel("Profits", fontsize =16)
# ax1.set_xlabel("c", fontsize =16)
# #ax1.set_title("Profits", fontsize =16)
# # ax1.grid(axis='y', color ='#666666',lw=0.25)
# ax1.legend(prop=dict(size=9), frameon=False)


# fig2 = plt.figure(figsize=(8, 4.5))
# ax2 = fig2.add_subplot(1, 1, 1)
# ax2.plot(sel_c, sel_prices_u, 'r', label="Uniform pricing",
#          linestyle='dotted',linewidth=2)
# ax2.plot(sel_c, [x[0] for x in sel_prices_d], 
#          label="Online price in Dual pricing", linestyle="dashdot", linewidth=2)
# ax2.plot(sel_c, [x[1] for x in sel_prices_d], 
#          label="Offline price in Dual pricing",linestyle="--" ,linewidth=2)
# ax2.set_ylabel("Prices", fontsize =16)
# ax2.set_xlabel("c", fontsize =16)
# ax2.legend(prop=dict(size=9), frameon=False,loc=4)
# # ax2.grid(axis='y', color ='#666666',lw=0.25)

# ## adjust figures
# ax1.set_xlim([0.14, 0.31])
# ax1.set_ylim([0, 0.08])
# ax1.axvline(x=0.14, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
# ax1.axvline(x=0.175, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
# ax1.axvline(x=0.223, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
# ax1.axvline(x=0.232, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
# ax1.text(0.15,0.02, 'zone 1')
# ax1.annotate("zone 2", xy=(0.225, 0.02), xytext=(0.24, 0.02),arrowprops=dict(arrowstyle="<-"))

# ax2.set_xlim([0.14,0.31])
# ax2.set_ylim([0,0.8])
# ax2.axvline(x=0.14, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
# ax2.axvline(x=0.175, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
# ax2.axvline(x=0.223, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
# ax2.axvline(x=0.232, ymin=0, ymax=1,linestyle = '-.',lw=0.5,color="black")
# ax2.text(0.15,0.1, 'zone 1')
# ax2.annotate("zone 2", xy=(0.225, 0.2), xytext=(0.24, 0.2),arrowprops=dict(arrowstyle="<-"))

# %%
# save figures

fig1.savefig("./MR_PFT.pdf")
fig2.savefig("./MR_PCE.pdf")
fig1.savefig("./MR_PFT.eps")
fig2.savefig("./MR_PCE.eps")


plt.show()

# %% [markdown]
# ## cal utility

# %%
def get_utility(TYPE, p, poff, c, con):

    if p >= 0.1:
        delta = 0.4
    else:
        delta = 0.4

    if TYPE == "H":
        theta = 1.00
    elif TYPE == "L":
        theta = 0.52
    else:
        raise Exception("Consumer Type Error!")

    u_store = (theta - poff) / 2 - c
    u_online = (theta - 2 * p + delta * p) / 2 - con
    u_showrooming = (theta - p - con) / 2 - c

    u_store = int(u_store * 10000 + 0.5) / 10000
    u_online = int(u_online * 10000 + 0.5) / 10000
    u_showrooming = int(u_showrooming * 10000 + 0.5) / 10000

    return u_store, u_online, u_showrooming

# %%
print(get_utility("H", p=0.46, poff=0.6, c=0.20, con=0.14))
print(get_utility("L", p=0.46, poff=0.6, c=0.20, con=0.14))
# Out:
# (0.0, -0.0079, 0.0)
# (-0.2399, -0.2479, -0.2399)

# %%
print(get_utility("H", p=0.4, poff=0.54, c=0.23, con=0.14))
print(get_utility("L", p=0.4, poff=0.54, c=0.23, con=0.14))
# Out:
# (0.0, 0.04, 0.0)
# (-0.2399, -0.1999, -0.2399)

# %%
print((2*0.2 - 0.14) / (1-0.4))
print((2*0.23 - 0.14) / (1-0.4))
# Out:
# 0.43333333333333335
# 0.5333333333333333

# %%
print(get_utility("H", p=0.4, poff=0.54, c=0.23, con=0))
print(get_utility("L", p=0.4, poff=0.54, c=0.23, con=0))
# Out:
# (0.0, 0.18, 0.07)
# (-0.2399, -0.0599, -0.1699)

# %%
print(get_utility("H", p=0.4, poff=0.54, c=0.23, con=1))
print(get_utility("L", p=0.4, poff=0.54, c=0.23, con=1))
# Out:
# (0.0, -0.8199, -0.4299)
# (-0.2399, -1.0599, -0.6699)
